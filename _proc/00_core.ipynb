# %% [raw]
# ---
# description: A set of utilities to work with legal documents
# output-file: core.html
# title: documents
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(say_hello)
# Out:
# ---
#
# ### say_hello
#
# >      say_hello (to)
#
# Say hello to somebody

# %%
assert say_hello("Isaac") == "Hello Isaac!"

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# ### foo
#
# >      foo ()
